# %% [markdown]
# # Importing Required Libraries

# %%
import re
import os
import multiprocessing
from bs4 import BeautifulSoup
from queue import Queue, Empty
from concurrent.futures import ThreadPoolExecutor
from urllib.parse import urljoin, urlparse
import requests
import html5lib
from os import listdir
from os.path import join, abspath
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from rank_bm25 import BM25Okapi

# %% [markdown]
# # Making a crawler using BeautifulSoup

# %%
class Crawler:
    
    def __init__(self, seed_url):
        self.seed_url = seed_url
        self.root_url = '{}://{}'.format(urlparse(self.seed_url).scheme, urlparse(self.seed_url).netloc)
        self.pool = ThreadPoolExecutor(max_workers=5)
        self.scraped_pages = set([])
        self.crawl_queue = Queue()
        self.crawl_queue.put(self.seed_url)

    def parse_links(self, html):
        soup = BeautifulSoup(html, 'html.parser')
        Anchor_Tags = soup.find_all('a', href=True)
        for link in Anchor_Tags:
            url = link['href']
            if url.startswith('/') or url.startswith(self.root_url):
                url = urljoin(self.root_url, url)
            if url not in self.scraped_pages:
                self.crawl_queue.put(url)

    def scrape_info(self, html):
        soup = BeautifulSoup(html, "html5lib")
        web_page_paragraph_contents = soup('p')
        text = ''
        for para in web_page_paragraph_contents:
            if not ('https:' in str(para.text)):
                text = text + str(para.text).strip()
        return

    def post_scrape_callback(self, res):
        result = res.result()
        if result and result.status_code == 200:
            self.parse_links(result.text)
            self.scrape_info(result.text)

    def scrape_page(self, url):
        try:
            res = requests.get(url, timeout=(3, 30))
            return res
        except requests.RequestException:
            return

    def run_crawler(self):
        for i in range(1,2000):
            try:
                target_url = self.crawl_queue.get(timeout=60)
                if target_url not in self.scraped_pages:
                    print("Crawling URL: {}".format(target_url))
                    self.current_scraping_url = "{}".format(target_url)
                    self.scraped_pages.add(target_url)
                    job = self.pool.submit(self.scrape_page, target_url)
                    job.add_done_callback(self.post_scrape_callback)
            except Empty:
                return
            except Exception as e:
                print(e)
                continue

    def info(self):
        print('Crawled pages are: ', self.scraped_pages, '\n')

    def save_to_text(self):
        file = open('link_data.txt', 'x', encoding="UTF-8")
        for i in self.scraped_pages:
            file.write(i+'\n')
        file.close()
        print('File Created')

# %% [markdown]
# # Giving a seed link to crawl the webpages

# %%
es = Crawler("https://medium.com/")
es.run_crawler()    
es.info()
es.save_to_text()
# Out:
# Crawling URL: https://medium.com/
# Crawling URL: https://medium.com/about?autoplay=1
# Crawling URL: https://medium.com/membership
# Crawling URL: https://about.medium.com/creators/
# Crawling URL: https://medium.com/m/signin?operation=login&redirect=https%3A%2F%2Fmedium.com%2F&source=--------------------------lo_home_nav-----------
# Crawling URL: https://medium.com/m/signin?operation=register&redirect=https%3A%2F%2Fmedium.com%2F&source=--------------------------lo_home_nav-----------
# Crawling URL: https://medium.com/@x_TomCooper_x?source=home---------0---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://medium.com/@x_TomCooper_x/ukraine-war-19-december-2022-d7b25da87e10?source=home---------0---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://medium.com/@tedbauer?source=home---------1---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://tedbauer.medium.com/university-of-idaho-murders-now-it-looks-like-john-jack-showalter-right-efbe57a2cd17?source=home---------1---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://medium.com/picnic-engineering?source=home---------2---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://medium.com/@sander.mak?source=home---------2---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://blog.picnic.nl/why-picnic-picked-java-e53fafe0df1b?source=home---------2---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://medium.com/@jamesmsama?source=home---------3---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://jamesmsama.medium.com/12-signs-youre-with-an-emotionally-mature-man-7c2e86dcfbd6?source=home---------3---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://medium.com/cantors-paradise?source=home---------4---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://medium.com/@piggsboson?source=home---------4---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://www.cantorsparadise.com/ramanujans-magnificent-formula-for-pi-9801-1103-8-%CF%80-22fd7197d650?source=home---------4---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://medium.com/user-experience-design-1?source=home---------5---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://medium.com/@dianamalewicz?source=home---------5---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://uxdesign.cc/2023-visual-design-trends-guide-82e84f09cbdf?source=home---------5---------------------2e6ea8c8_9be9_4a0c_9128_333094b012cc-------7
# Crawling URL: https://medium.com/tag/programming?source=home-------------------------------------
# Crawling URL: https://medium.com/tag/data-science?source=home-------------------------------------
# Crawling URL: https://medium.com/tag/technology?source=home-------------------------------------
# Crawling URL: https://medium.com/tag/self-improvement?source=home-------------------------------------
# Crawling URL: https://medium.com/tag/writing?source=home-------------------------------------
# Crawling URL: https://medium.com/tag/relationships?source=home-------------------------------------
# Crawling URL: https://medium.com/tag/machine-learning?source=home-------------------------------------
# Crawling URL: https://medium.com/tag/productivity?source=home-------------------------------------
# Crawling URL: https://medium.com/tag/politics?source=home-------------------------------------
# Crawling URL: https://medium.com/@drtomfrieden?source=home---------0------------------0----------
# Crawling URL: https://drtomfrieden.medium.com/understanding-long-covid-9c24f9150172?source=home---------0------------------0----------
# Crawling URL: https://medium.com/@davidbowles?source=home---------1------------------0----------
# Crawling URL: https://davidbowles.medium.com/toward-a-mexican-american-futurism-534b734e441b?source=home---------1------------------0----------
# Crawling URL: https://medium.com/invisible-illness?source=home---------2------------------0----------
# Crawling URL: https://medium.com/@edergenzinger?source=home---------2------------------0----------
# Crawling URL: https://medium.com/invisible-illness/learning-to-cope-with-estrangement-when-children-cancel-their-parents-914a4a80d2be?source=home---------2------------------0----------
# Crawling URL: https://medium.com/@tomsmith585?source=home---------3------------------0----------
# Crawling URL: https://tomsmith585.medium.com/chatgpt-is-having-a-thomas-edison-moment-8342dd70d2bd?source=home---------3------------------0----------
# Crawling URL: https://medium.com/forge?source=home---------4------------------0----------
# Crawling URL: https://medium.com/@allegra.e.hobbs?source=home---------4------------------0----------
# Crawling URL: https://forge.medium.com/spotifys-year-end-lists-are-the-ultimate-personality-test-46b742e11a22?source=home---------4------------------0----------
# Crawling URL: https://medium.com/@joulee?source=home---------5------------------0----------
# Crawling URL: https://joulee.medium.com/why-your-team-needs-a-weekly-metrics-review-dcc9cce7ac3c?source=home---------5------------------0----------
# Crawling URL: https://medium.com/@elliotgraebert?source=home---------6------------------0----------
# Crawling URL: https://medium.com/@elliotgraebert/tyrion-lannister-and-the-7-habits-of-highly-effective-people-ee572a276064?source=home---------6------------------0----------
# Crawling URL: https://medium.com/@zephoria?source=home---------7------------------0----------
# Crawling URL: https://zephoria.medium.com/what-if-failure-is-the-plan-2f219ea1cd62?source=home---------7------------------0----------
# Crawling URL: https://medium.com/@efeng?source=home---------8------------------0----------
# Crawling URL: https://efeng.medium.com/why-are-there-so-many-web3-startups-43a150379d52?source=home---------8------------------0----------
# Crawling URL: https://medium.com/@chasten?source=home---------9------------------0----------
# Crawling URL: https://chasten.medium.com/what-marriage-means-to-me-a6bdd72cffe1?source=home---------9------------------0----------
# Crawling URL: https://help.medium.com/hc/en-us?source=home-------------------------------------
# Crawling URL: https://medium.statuspage.io/?source=home-------------------------------------
# Crawling URL: https://about.medium.com/creators/?source=home-------------------------------------
# Crawling URL: https://blog.medium.com/?source=home-------------------------------------
# Crawling URL: https://medium.com/jobs-at-medium/work-at-medium-959d1a85284e?source=home-------------------------------------
# Crawling URL: https://policy.medium.com/medium-privacy-policy-f03bf92035c9?source=home-------------------------------------
# Crawling URL: https://policy.medium.com/medium-terms-of-service-9db0094a1e0f?source=home-------------------------------------
# Crawling URL: https://medium.com/about?autoplay=1&source=home-------------------------------------
# Crawling URL: https://speechify.com/medium?source=home-------------------------------------
# Crawling URL: https://medium.com/?source=home-------------------------------------
# Crawling URL: https://itunes.apple.com/app/medium-everyones-stories/id828256236?pt=698524&mt=8&ct=home&source=home-------------------------------------
# Crawling URL: https://play.google.com/store/apps/details?id=com.medium.reader&source=home-------------------------------------
# Crawling URL: https://medium.com/?source=membership_page---nav_logo-----------------------membership_page_nav_logo-&utm_source=membership&utm_medium=landing-page&utm_campaign=home&utm_content=top-nav
# Crawling URL: https://medium.com/about?source=membership_page---about_top_nav_link-----------------------membership_page_about_top_nav_link-&utm_source=membership&utm_medium=landing-page&utm_campaign=about&utm_content=top-nav
# Crawling URL: https://medium.com/membership?source=membership_page---membership_top_nav_link-----------------------membership_page_membership_top_nav_link-&utm_source=membership&utm_medium=landing-page&utm_campaign=membership&utm_content=top-nav
# Crawling URL: https://medium.com/creators?source=membership_page---creators_top_nav_link-----------------------membership_page_creators_top_nav_link-&utm_source=membership&utm_medium=landing-page&utm_campaign=creators&utm_content=top-nav
# Crawling URL: https://medium.com/m/signin?source=membership_page---nav_signin-----------------------membership_page_nav_signin-&utm_source=membership&utm_medium=landing-page&utm_campaign=signin&utm_content=top-nav
# Crawling URL: https://medium.com/plans?source=membership_page---nav_cta-----------------------membership_page_nav_cta-&utm_source=membership&utm_medium=landing-page&utm_campaign=plans&utm_content=top-nav
# Crawling URL: https://medium.com/creators
# Crawling URL: https://medium.com/plans?source=membership_page---hero_cta-----------------------membership_page_hero_cta-&amp;utm_source=membership&amp;utm_medium=landing-page&amp;utm_campaign=plans&amp;utm_content=hero
# Crawling URL: https://medium.com/plans?source=membership_page---footer_cta-----------------------membership_page_footer_cta-&utm_source=membership&utm_medium=landing-page&utm_campaign=plans&utm_content=module
# Crawling URL: https://medium.com/about
# Crawling URL: https://policy.medium.com/medium-terms-of-service-9db0094a1e0f
# Crawling URL: https://help.medium.com
# Crawling URL: https://medium.com/?source=about_page---nav_logo-----------------------about_page_nav_logo-&utm_source=about&utm_medium=landing-page&utm_campaign=home&utm_content=top-nav
# Crawling URL: https://medium.com/about?source=about_page---about_top_nav_link-----------------------about_page_about_top_nav_link-&utm_source=about&utm_medium=landing-page&utm_campaign=about&utm_content=top-nav
# Crawling URL: https://medium.com/membership?source=about_page---membership_top_nav_link-----------------------about_page_membership_top_nav_link-&utm_source=about&utm_medium=landing-page&utm_campaign=membership&utm_content=top-nav
# Crawling URL: https://medium.com/creators?source=about_page---creators_top_nav_link-----------------------about_page_creators_top_nav_link-&utm_source=about&utm_medium=landing-page&utm_campaign=creators&utm_content=top-nav
# Crawling URL: https://medium.com/m/signin?source=about_page---nav_signin-----------------------about_page_nav_signin-&utm_source=about&utm_medium=landing-page&utm_campaign=signin&utm_content=top-nav
# Crawling URL: https://medium.com/m/signin?source=about_page---nav_cta-----------------------about_page_nav_cta-&utm_source=about&utm_medium=landing-page&utm_campaign=cta&utm_content=top-nav
# Crawling URL: https://ericadhawan.medium.com/
# Crawling URL: https://medium.com/@profgalloway
# Crawling URL: https://onezero.medium.com
# Crawling URL: https://sarahcottrell.medium.com/
# Crawling URL: https://devonprice.medium.com/
# Crawling URL: https://kokumura.medium.com/
# Crawling URL: https://carvellwallace.medium.com/
# Crawling URL: https://forge.medium.com
# Crawling URL: https://gen.medium.com
# Crawling URL: https://est1865.medium.com/
# Crawling URL: https://elemental.medium.com
# Crawling URL: https://level.medium.com/
# Crawling URL: https://medium.com/plans?source=about_page---membership_module_link-----------------------about_page_membership_module_link-&utm_source=about&utm_medium=landing-page&utm_campaign=plans&utm_content=module
# Crawling URL: https://apps.apple.com/us/app/medium/id828256236
# Crawling URL: https://play.google.com/store/apps/details?id=com.medium.reader&hl=en_US
# Crawling URL: https://blog.medium.com/?source=about_page---blog_module_link-----------------------about_page_blog_module_link-&utm_source=about&utm_medium=landing-page&utm_campaign=blog&utm_content=module
# Crawling URL: https://jobs.medium.com/?source=about_page---jobs_module_link-----------------------about_page_jobs_module_link-&utm_source=about&utm_medium=landing-page&utm_campaign=jobs&utm_content=module
# Crawling URL: https://medium.com/m/signin?source=about_page---footer_cta-----------------------about_page_footer_cta-&utm_source=about&utm_medium=landing-page&utm_campaign=signin&utm_content=module
# Crawling URL: https://medium.com/?source=about_page---footer_logo-----------------------about_page_footer_logo-&utm_source=about&utm_medium=landing-page&utm_campaign=home&utm_content=footer-logo
# Crawling URL: https://medium.com/?source=creator_tools_page---nav_logo-----------------------creator_tools_page_nav_logo-&utm_source=creator-tools&utm_medium=landing-page&utm_campaign=home&utm_content=top-nav
# Crawling URL: https://medium.com/about?source=creator_tools_page---about_top_nav_link-----------------------creator_tools_page_about_top_nav_link-&utm_source=creator-tools&utm_medium=landing-page&utm_campaign=about&utm_content=top-nav
# Crawling URL: https://medium.com/membership?source=creator_tools_page---membership_top_nav_link-----------------------creator_tools_page_membership_top_nav_link-&utm_source=creator-tools&utm_medium=landing-page&utm_campaign=membership&utm_content=top-nav
# Crawling URL: https://medium.com/new-story?source=creator_tools_page---creators_top_nav_link-----------------------creator_tools_page_creators_top_nav_link-&utm_source=creator-tools&utm_medium=landing-page&utm_campaign=editor&utm_content=top-nav
# Crawling URL: https://medium.com/m/signin?source=creator_tools_page---nav_signin-----------------------creator_tools_page_nav_signin-&utm_source=creator-tools&utm_medium=landing-page&utm_campaign=signin&utm_content=top-nav
# Crawling URL: https://medium.com/new-story?source=creator_tools_page---nav_cta-----------------------creator_tools_page_cta_nav-&utm_source=creator-tools&utm_medium=landing-page&utm_campaign=editor&utm_content=top-nav
# Crawling URL: https://medium.com/new-story?source=creator_tools_page---hero_cta-----------------------creator_tools_page_hero_cta-&utm_source=creator-tools&utm_medium=landing-page&utm_campaign=editor&utm_content=hero
# Crawling URL: https://medium.com/m/signin?source=creators_page---mobile_hero-----------------------creators_page_mobile_hero-
# Crawling URL: https://about.medium.com/creator-tools
# Crawling URL: https://barackobama.medium.com/
# Crawling URL: https://michaelchabon.medium.com/
# Crawling URL: https://skamille.medium.com/
# Crawling URL: https://susanorlean.medium.com/
# Crawling URL: https://medium.com/new-story?source=creators_page---start_writing_module&utm_source=creators&utm_medium=landing-page&utm_campaign=newstory&utm_content=module
# Crawling URL: http://medium.com/me
# Crawling URL: https://help.medium.com/hc/en-us/articles/215108608-Your-stats
# Crawling URL: https://help.medium.com/hc/en-us/articles/115004746907-Connect-social-media-accounts
# Crawling URL: https://help.medium.com/hc/en-us/articles/224488047-Control-your-recommendations

# Crawling URL: https://medium.com/picnic-engineering?source=user_profile---------0----------------------------
# Crawling URL: https://medium.com/picnic-engineering/why-picnic-picked-java-e53fafe0df1b?source=user_profile---------0----------------------------
# Crawling URL: https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fbookmark%2Fp%2Fe53fafe0df1b&operation=register&redirect=https%3A%2F%2Fblog.picnic.nl%2Fwhy-picnic-picked-java-e53fafe0df1b&source=---------0-----------------bookmark_preview-----------
# Crawling URL: https://medium.com/picnic-engineering?source=user_profile---------1----------------------------
# Crawling URL: https://medium.com/picnic-engineering/picnic-open-sources-error-prone-support-b23f9a7208b6?source=user_profile---------1----------------------------
# Crawling URL: https://medium.com/tag/java?source=user_profile--------------------java-----------------
# Crawling URL: https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fbookmark%2Fp%2Fb23f9a7208b6&operation=register&redirect=https%3A%2F%2Fblog.picnic.nl%2Fpicnic-open-sources-error-prone-support-b23f9a7208b6&source=---------1-----------------bookmark_preview-----------
# Crawling URL: https://medium.com/picnic-engineering?source=user_profile---------2----------------------------
# Crawling URL: https://medium.com/picnic-engineering/embracing-java-17-heres-what-we-learned-69779d95fdf2?source=user_profile---------2----------------------------
# Crawling URL: https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fbookmark%2Fp%2F69779d95fdf2&operation=register&redirect=https%3A%2F%2Fblog.picnic.nl%2Fembracing-java-17-heres-what-we-learned-69779d95fdf2&source=---------2-----------------bookmark_preview-----------
# Crawling URL: https://medium.com/picnic-engineering?source=user_profile---------3----------------------------
# Crawling URL: https://medium.com/picnic-engineering/software-architecture-for-scale-ups-9c11cb6e1c7e?source=user_profile---------3----------------------------
# Crawling URL: https://medium.com/tag/software-architecture?source=user_profile--------------------software_architecture-----------------
# Crawling URL: https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fbookmark%2Fp%2F9c11cb6e1c7e&operation=register&redirect=https%3A%2F%2Fblog.picnic.nl%2Fsoftware-architecture-for-scale-ups-9c11cb6e1c7e&source=---------3-----------------bookmark_preview-----------
# Crawling URL: https://medium.com/picnic-engineering?source=user_profile---------4----------------------------
# Crawling URL: https://medium.com/picnic-engineering/scaling-picnic-systems-in-corona-times-701699aa513b?source=user_profile---------4----------------------------
# Crawling URL: https://medium.com/tag/scaling?source=user_profile--------------------scaling-----------------
# Crawling URL: https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fbookmark%2Fp%2F701699aa513b&operation=register&redirect=https%3A%2F%2Fblog.picnic.nl%2Fscaling-picnic-systems-in-corona-times-701699aa513b&source=---------4-----------------bookmark_preview-----------
# Crawling URL: https://medium.com/picnic-engineering?source=user_profile---------5----------------------------
# Crawling URL: https://medium.com/picnic-engineering/codeone-2019-the-state-of-java-56ff69b9ef5d?source=user_profile---------5----------------------------
# Crawling URL: https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fbookmark%2Fp%2F56ff69b9ef5d&operation=register&redirect=https%3A%2F%2Fblog.picnic.nl%2Fcodeone-2019-the-state-of-java-56ff69b9ef5d&source=---------5-----------------bookmark_preview-----------
# Crawling URL: https://medium.com/97-things?source=user_profile---------6----------------------------
# Crawling URL: https://medium.com/97-things/the-rebirth-of-java-77d9606848d9?source=user_profile---------6----------------------------
# Crawling URL: https://medium.com/tag/97-things?source=user_profile--------------------97_things-----------------
# Crawling URL: https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fbookmark%2Fp%2F77d9606848d9&operation=register&redirect=https%3A%2F%2Fmedium.com%2F97-things%2Fthe-rebirth-of-java-77d9606848d9&source=---------6-----------------bookmark_preview-----------
# Crawling URL: https://medium.com/@sander.mak?source=---two_column_layout_sidebar----------------------------------
# Crawling URL: https://medium.com/@sander.mak/followers?source=---two_column_layout_sidebar----------------------------------
# Crawling URL: http://javamodularity.com
# Crawling URL: http://bit.ly/ps-sander
# Crawling URL: https://medium.com/m/signin?actionUrl=%2F_%2Fapi%2Fsubscriptions%2Fnewsletters%2F5ff4e5c1b93f&operation=register&redirect=https%3A%2F%2Fmedium.com%2F%40sander.mak&newsletterV3=e77092f1acb5&newsletterV3Id=5ff4e5c1b93f&user=Sander+Mak&userId=e77092f1acb5&source=---two_column_layout_sidebar-----------------------subscribe_user-----------
# Crawling URL: https://medium.com/?source=post_page-----7c2e86dcfbd6--------------------------------
# Crawling URL: https://medium.com/m/signin?actionUrl=%2F_%2Fapi%2Fsubscriptions%2Fnewsletters%2Fe0ba667c847a&operation=register&redirect=https%3A%2F%2Fjamesmsama.medium.com%2F12-signs-youre-with-an-emotionally-mature-man-7c2e86dcfbd6&newsletterV3=af16e517223d&newsletterV3Id=e0ba667c847a&user=James+Michael+Sama&userId=af16e517223d&source=-----7c2e86dcfbd6---------------------subscribe_user-----------
# Crawling URL: https://knowable.fyi/?utm_source=medium&utm_medium=referral&utm_campaign=medium-post-footer&source=post_page-----7c2e86dcfbd6--------------------------------
# Crawling URL: https://medium.com/?source=post_internal_links---------0----------------------------
# Crawling URL: https://medium.com/9-traits-of-a-high-quality-man-and-how-to-attract-him-865708ff1e1?source=post_internal_links---------0----------------------------
# Crawling URL: https://beyourownbrandofsexy.medium.com/?source=post_internal_links---------1----------------------------
# ...
# Crawling URL: https://medium.com/@renukagavrani?source=topics_v2---------4-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/@renukagavrani/how-i-am-prioritizing-the-things-that-i-cherish-the-most-have-a-sweet-time-for-yourself-9baf291b6159?source=topics_v2---------4-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/tag/life-lessons?source=topic_page--------------------life_lessons-----------------
# Crawling URL: https://medium.com/tag/life?source=topic_page--------------------life-----------------
# Crawling URL: https://medium.com/tag/personal-development?source=topic_page--------------------personal_development-----------------
# Crawling URL: https://medium.com/tag/self?source=topic_page--------------------self-----------------
# Crawling URL: https://medium.com/tag/productivity?source=topic_page--------------------productivity-----------------
# Crawling URL: https://medium.com/tag/writing?source=topic_page--------------------writing-----------------
# Crawling URL: https://medium.com/tag/inspiration?source=topic_page--------------------inspiration-----------------
# Crawling URL: https://medium.com/tag/mental-health?source=topic_page--------------------mental_health-----------------
# Crawling URL: https://medium.com/tag/psychology?source=topic_page--------------------psychology-----------------
# Crawling URL: https://medium.com/@chef-boyardeji?source=topics_v2---------5-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/practice-in-public?source=topics_v2---------5-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/practice-in-public/stop-apologizing-for-your-existence-32edfea43570?source=topics_v2---------5-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/@maribelwood4678?source=topics_v2---------6-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/@maribelwood4678/5-common-time-wasting-habits-and-how-to-avoid-them-93c65e045df3?source=topics_v2---------6-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/@arana3?source=topics_v2---------7-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/@arana3/new-years-resolutions-of-a-22-year-old-3528b5a8de75?source=topics_v2---------7-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/@BilalTosif?source=topics_v2---------8-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/@BilalTosif/19-pieces-of-advice-i-would-give-to-my-15-year-old-self-b47f5509357?source=topics_v2---------8-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/@james-white69?source=topics_v2---------9-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/mind-cafe?source=topics_v2---------9-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/mind-cafe/jeff-bezos-wants-you-to-read-these-books-in-2023-d79e1fe6d3a3?source=topics_v2---------9-84--------------------48f98a21_684f_4d1e_b75c_a4541bcc0ccc-------17
# Crawling URL: https://medium.com/tag/life-lessons?source=topics_v2---two_column_layout_sidebar------0-----------life_lessons-------28----------
# Crawling URL: https://medium.com/tag/life?source=topics_v2---two_column_layout_sidebar------1-----------life-------28----------
# Crawling URL: https://medium.com/tag/personal-development?source=topics_v2---two_column_layout_sidebar------2-----------personal_development-------28----------
# Crawling URL: https://medium.com/tag/self?source=topics_v2---two_column_layout_sidebar------3-----------self-------28----------
# Crawling URL: https://medium.com/tag/productivity?source=topics_v2---two_column_layout_sidebar------4-----------productivity-------28----------
# Crawling URL: https://medium.com/tag/writing?source=topics_v2---two_column_layout_sidebar------5-----------writing-------28----------
# Crawling URL: https://medium.com/tag/inspiration?source=topics_v2---two_column_layout_sidebar------6-----------inspiration-------28----------
# Crawling URL: https://medium.com/tag/mental-health?source=topics_v2---two_column_layout_sidebar------7-----------mental_health-------28----------
# Crawling URL: https://medium.com/tag/psychology?source=topics_v2---two_column_layout_sidebar------8-----------psychology-------28----------
# Crawling URL: https://medium.com/@nickwignall?source=-857388aceb0e--two_column_layout_sidebar------0----------------------------
# Crawling URL: https://medium.com/@seanjkernan?source=-51e7eb466f57--two_column_layout_sidebar------2----------------------------
# Crawling URL: https://medium.com/@anangsha?source=-6e2475a6e38a--two_column_layout_sidebar------3----------------------------
# Crawling URL: https://medium.com/@darshakrana?source=-1dbd1f7e22bc--two_column_layout_sidebar------4----------------------------
# Crawling URL: https://medium.com/tag/self-improvement/archive?source=---two_column_layout_sidebar----------------------------------
# Crawling URL: https://rsci.app.link/?%24canonical_url=https%3A%2F%2Fmedium.com%2Fp%2F82e84f09cbdf&%7Efeature=LoOpenInAppButton&%7Echannel=ShowPostUnderCollection&source=---two_column_layout_nav----------------------------------
# Crawling URL: https://medium.com/m/signin?operation=register&redirect=https%3A%2F%2Fuxdesign.cc%2F2023-visual-design-trends-guide-82e84f09cbdf&source=post_page---two_column_layout_nav-----------------------global_nav-----------
# Crawling URL: https://medium.com/m/signin?operation=login&redirect=https%3A%2F%2Fuxdesign.cc%2F2023-visual-design-trends-guide-82e84f09cbdf&source=post_page---two_column_layout_nav-----------------------global_nav-----------
# Crawling URL: https://uxdesign.cc/?source=post_page-----82e84f09cbdf--------------------------------
# Crawling URL: https://medium.com/@dianamalewicz?source=post_page-----82e84f09cbdf--------------------------------
# Crawling URL: https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fsubscribe%2Fuser%2Fa5f0023e15de&operation=register&redirect=https%3A%2F%2Fuxdesign.cc%2F2023-visual-design-trends-guide-82e84f09cbdf&user=Diana+Malewicz&userId=a5f0023e15de&source=post_page-a5f0023e15de----82e84f09cbdf---------------------follow_byline-----------
# Crawling URL: https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fbookmark%2Fp%2F82e84f09cbdf&operation=register&redirect=https%3A%2F%2Fuxdesign.cc%2F2023-visual-design-trends-guide-82e84f09cbdf&source=--------------------------bookmark_header-----------
# Crawling URL: https://www.esteelauderanrcade.com/en-us/
# Crawling URL: http://www.apple.com
# Crawling URL: https://nexusstudios.com/work/duolingo/
# Crawling URL: https://2022.thisispam.com/
# Crawling URL: https://atelier.net/virtual-economy/
# Crawling URL: https://wickret.cuberto.com/
# Crawling URL: https://midwam.com/en
# Crawling URL: https://greensock.com/showcase/
# Crawling URL: https://artsexperiments.withgoogle.com/meroe/
# Crawling URL: https://www.coinbase.com/
# Crawling URL: https://www.airbnb.com/
# Crawling URL: https://dribbble.com/tranmautritam
# Crawling URL: https://fohandboh.com/
# Crawling URL: https://www.revolut.com/cards/
# Crawling URL: https://www.apple.com/iphone-14/
# Crawling URL: https://www.sketch.com/apps/
# Crawling URL: https://www.ls.graphics/
# Crawling URL: https://www.winamp.com/
# Crawling URL: https://cosmos.network/
# Crawling URL: https://getuntil.app/
# Crawling URL: https://stripe.com/
# Crawling URL: https://joinclyde.com/
# Crawling URL: https://www.apple.com/
# Crawling URL: https://vercel.com/
# Crawling URL: https://www.memorisely.com/
# Crawling URL: https://www.uber.com/pl/en/
# Crawling URL: https://endel.io/
# Crawling URL: https://www.revolut.com/business/cards/
# Crawling URL: https://homey.app/en-us/
# Crawling URL: https://www.klarna.com/uk/
# Crawling URL: https://www.dropbox.com/
# Crawling URL: https://github.com/
# Crawling URL: https://play.google.com/store/apps/details?id=app.zenly.locator&hl=pl&gl=US
# Crawling URL: https://railway.app/
# Crawling URL: https://linear.app/
# Crawling URL: https://www.notion.so/product/ai
# Crawling URL: https://www.create.video/
# Crawling URL: https://solana.com/
# Crawling URL: https://letter.co/deposit
# Crawling URL: https://www.thoughtlab.com
# Crawling URL: https://apps.apple.com/us/app/youtube-music/id1017492454
# Crawling URL: https://nextjs.org
# Crawling URL: https://dribbble.com/glebich
# Crawling URL: http://letter.co
# Crawling URL: https://heartaerospace.com/
# Crawling URL: https://theothersideoftruth.com
# Crawling URL: https://increase.com
# Crawling URL: https://gumroad.com/
# Crawling URL: https://about.instagram.com/brand/
# Crawling URL: https://fonts.google.com/featured
# Crawling URL: https://www.fontshare.com/
# Crawling URL: https://medium.com/user-experience-design-1/most-amazing-fonts-you-shouldnt-miss-in-2022-ad37031e04b4
# Crawling URL: https://www.helloharbor.com
# Crawling URL: https://beautifulbydrew.com
# Crawling URL: https://www.vacation.inc
# Crawling URL: https://www.frankys-hats.com
# Crawling URL: https://apps.apple.com/us/app/how-we-feel/id1562706384
# Crawling URL: https://www.expressvpn.com
# Crawling URL: https://cydstumpel.nl/
# Crawling URL: https://medium.com/@dianamalewicz
# Crawling URL: https://hype4.com/
# Crawling URL: https://medium.com/tag/ui?source=post_page-----82e84f09cbdf---------------ui-----------------
# Crawling URL: https://medium.com/tag/trends?source=post_page-----82e84f09cbdf---------------trends-----------------
# Crawling URL: https://medium.com/tag/2023?source=post_page-----82e84f09cbdf---------------2023-----------------
# Crawling URL: https://medium.com/tag/design?source=post_page-----82e84f09cbdf---------------design-----------------
# Crawling URL: https://medium.com/tag/visual-design?source=post_page-----82e84f09cbdf---------------visual_design-----------------
# Crawling URL: https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fvote%2Fuser-experience-design-1%2F82e84f09cbdf&operation=register&redirect=https%3A%2F%2Fuxdesign.cc%2F2023-visual-design-trends-guide-82e84f09cbdf&user=Diana+Malewicz&userId=a5f0023e15de&source=-----82e84f09cbdf---------------------clap_footer-----------
# Crawling URL: https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fbookmark%2Fp%2F82e84f09cbdf&operation=register&redirect=https%3A%2F%2Fuxdesign.cc%2F2023-visual-design-trends-guide-82e84f09cbdf&source=--------------------------bookmark_footer-----------
# Crawling URL: https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fsubscribe%2Fcollection%2Fuser-experience-design-1%2F82e84f09cbdf&operation=register&redirect=https%3A%2F%2Fuxdesign.cc%2F2023-visual-design-trends-guide-82e84f09cbdf&collection=UX+Collective&collectionId=138adf9c44c&source=post_page-----82e84f09cbdf---------------------follow_footer-----------
# Crawling URL: https://medium.com/@karin.m.wahlberg?source=post_internal_links---------0----------------------------
# Crawling URL: https://medium.com/anothertomorrow?source=post_internal_links---------0----------------------------
# Crawling URL: https://medium.com/anothertomorrow/so-you-ran-a-design-sprint-now-what-a41849d02b05?source=post_internal_links---------0----------------------------
# Crawling URL: https://aridutilh.medium.com/?source=post_internal_links---------1----------------------------
# Crawling URL: https://aridutilh.medium.com/my-unanswerable-question-33a09a7ad840?source=post_internal_links---------1----------------------------
# Crawling URL: https://realvjy.medium.com/?source=post_internal_links---------2----------------------------
# Crawled pages are:  {'https://blog.picnic.nl/@joao.nogueira01', 'https://www.cantorsparadise.com/the-black-scholes-formula-explained-9e05b7865d8a?source=collection_home---4------2-----------------------', 'https://medium.com/picnic-engineering/embracing-java-17-heres-what-we-learned-69779d95fdf2?source=user_profile---------2----------------------------', 'https://blog.picnic.nl/@dylan.goldsborough', 'https://rebeccaheuterkasowicz.medium.com/?source=post_internal_links---------2----------------------------', 'https://rsci.app.link/?%24canonical_url=https%3A%2F%2Fmedium.com%2Fp%2F22fd7197d650&%7Efeature=LoOpenInAppButton&%7Echannel=ShowPostUnderCollection&source=---two_column_layout_nav----------------------------------', 'https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fvote%2Fcantors-paradise%2F22fd7197d650&operation=register&redirect=https%3A%2F%2Fwww.cantorsparadise.com%2Framanujans-magnificent-formula-for-pi-9801-1103-8-%25CF%2580-22fd7197d650&user=Sunny+Labh&userId=cace67d704a3&source=-----22fd7197d650---------------------clap_footer-----------', 'https://medium.com/@abidihelmi2010/top-underdogs-in-fifa-world-cup-history-9c7d5cef66ea?source=topics_v2---------7-84--------------------2169c1d8_80bd_4c3e_9be1_0c59559fa1b1-------17', 'https://medium.com/ramanujans-magnificent-formula-for-pi-9801-1103-8-π-22fd7197d650?source=user_profile---------4----------------------------', 'https://homey.app/en-us/', 'https://blog.picnic.nl/picnic-analytics-platform-migration-from-aws-kinesis-to-confluent-cloud-adb06601c78?source=collection_home---4------21-----------------------', 'https://medium.com/@jennbaxter_69070/kidnapped-what-happened-to-david-blockett-1739ed5241bb?source=post_internal_links---------7----------------------------', 'https://michaelchabon.medium.com/', 'https://medium.com/becoming-a-multiplier-on-our-java-developer-platform-17fe87de2e20', 'https://medium.com/@x_TomCooper_x/ukraine-war-12-december-2022-52037ae30a06?source=user_profile---------5----------------------------', 'https://blog.picnic.nl/about', 'https://medium.com/@doctoreww?source=topics_v2---------3-84--------------------d39566fe_0c0a_406f_bc76_cefb310963c9-------17', 'https://medium.com/7-undeniable-benefits-of-self-love-939816073c98?source=user_profile---------5----------------------------', 'https://www.cantorsparadise.com/the-riemann-hypothesis-explained-fa01c1f75d3f?source=collection_home---4------0-----------------------', 'https://medium.com/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fbookmark%2Fp%2F22fd7197d650&operation=register&redirect=https%3A%2F%2Fwww.cantorsparadise.com%2Framanujans-magnificent-formula-for-pi-9801-1103-8-%25CF%2580-22fd7197d650&source=---------4-----------------bookmark_preview-----------', 'https://tiagovf.medium.com/?source=blogrolls_sidebar---two_column_layout_sidebar----------------------------------', 'https://medium.com/@anangsha?source=-6e2475a6e38a--two_column_layout_sidebar------3----------------------------', 'https://medium.com/@sanna.ab.rau?source=collection_home---------3----------------------------', 'https://medium.com/m/signin?actionUrl=%2F_%2Fapi%2Fsubscriptions%2Fnewsletters%2F8b00eaebc065&operation=register&redirect=https%3A%2F%2Ftedbauer.medium.com%2Funiversity-of-idaho-murders-now-it-looks-like-john-jack-showalter-right-efbe57a2cd17&newsletterV3=794a1c55cb75&newsletterV3Id=8b00eaebc065&user=Ted+Bauer&userId=794a1c55cb75&source=-----efbe57a2cd17---------------------subscribe_user-----------', 'https://www.cantorsparadise.com/@alexand3r-bird', 'https://medium.com/tag/technology/latest?source=topic_page-------------------------------------', 'https://medium.com/tag/confidence?source=user_profile--------------------confidence-----------------', 'https://medium.com/?source=post_internal_links---------0----------------------------', 'https://medium.com/anothertomorrow?source=post_internal_links---------0----------------------------', 'https://medium.com/new-story?source=topic_page------ ...
#
# File Created

# %% [markdown]
# # Getting all the links in URL to list

# %%
lis = []
lenstr = len("https://medium.com/")
with open('link_data.txt','r') as f:
    for line in f:
        k = line.strip()
        if k[:lenstr] ==  'https://medium.com/':
            lis.append(line.strip())
print(len(lis))
# Out:
# 646

# %% [markdown]
# # Dowloading all web pages with tags p (a.k.a. Paragraph)

# %%
def downloader(link):
    req = requests.get(link)
    req.encoding = "utf8"
    return req.text

k=0
lenstr = len("https://medium.com/")
for i in range(len(lis)):
    if lis[i][:lenstr]=="https://medium.com/":
        name = f'temper/'+"doc"+str(k)+".txt"
        contents = downloader(lis[i])
        soup = BeautifulSoup(contents, "html5lib")
        res = ''
        for i in range(len(soup.find_all('p'))):
            text = soup.find_all('p')[i].get_text()
            res = res + text
        with open(name,'a', encoding="UTF-8") as f1:
            f1.write(res)
            k+=1
        f1.close()
f1.close()

# %% [markdown]
# # Removing all text files of scraped sites which are empty

# %%
k = 2
for i in range(2, 646):
    if os.path.getsize(f'temper\doc{i}.txt') > 0:
        os.rename(f'temper\doc{i}.txt', f'temper\{k}.txt')
        k+=1
    else:
        os.remove(f'temper\doc{i}.txt')

# %% [markdown]
# # Getting all files in the directory of files

# %%
data_dir = 'temper/'
DATA_SET_DIR = abspath(data_dir)
print('\nGetting List of text files from' + DATA_SET_DIR)
files = listdir(DATA_SET_DIR)
print('\nFile list retrieved from ' + DATA_SET_DIR)
# Out:
# Getting List of text files fromd:\B.Tech\Semester - VII\CSE 419 Information Retrieval\Project\Docs
#
# File list retrieved from d:\B.Tech\Semester - VII\CSE 419 Information Retrieval\Project\Docs

# %% [markdown]
# # Getting Porter Stemming and stopwords

# %%
ps = PorterStemmer()
nltk_stop_words = set(stopwords.words('english'))

# %% [markdown]
# # Getting all the text after pre processing into list

# %%
corpus = []
for f in files:
	strm = open(DATA_SET_DIR + '/' + f, 'r', encoding="utf8")
	words = word_tokenize(strm.read())
	words = filter(lambda w: w not in nltk_stop_words, words)
	words = map(lambda w: ps.stem(str(w)), words)
	corpus.append(' '.join(words))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 corpus = []
# ----> 2 for f in files:
#       3 	strm = open(DATA_SET_DIR + '/' + f, 'r', encoding="utf8")
#       4 	words = word_tokenize(strm.read())
#
# NameError: name 'files' is not defined

# %% [markdown]
# # Getting tf-idf and making vectors

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(corpus)

# %% [markdown]
# # Making the Matrix of Cosine Similarity

# %%
cosine_matrix = cosine_similarity(tfidf_matrix)

# %% [markdown]
# # Printing the cosine similarty matrix

# %%
print(cosine_matrix)
# Out:
# [[1.         0.         0.00358598 ... 0.15183363 0.         0.01024462]
#  [0.         1.         0.04733177 ... 0.         0.09065896 0.03864335]
#  [0.00358598 0.04733177 1.         ... 0.00478615 0.07078646 0.02634958]
#  ...
#  [0.15183363 0.         0.00478615 ... 1.         0.         0.04862246]
#  [0.         0.09065896 0.07078646 ... 0.         1.         0.04791486]
#  [0.01024462 0.03864335 0.02634958 ... 0.04862246 0.04791486 1.        ]]

# %% [markdown]
# # Saving the cosine similarty matrix

# %%
cosine = []
for idx, row in enumerate(cosine_matrix):
    cosine.append(str(row))
with open('cosine_similarity.txt', 'w') as f:
    for line in cosine:
        f.write(f"{line}\n")

# %% [markdown]
# # Taking and Dividing the Corpus and to search

# %%
tokenized_corpus = [doc.split(" ") for doc in corpus]
bm25 = BM25Okapi(tokenized_corpus)

# %% [markdown]
# # Taking the Query from the user and and using bm25 to rank the documents

# %%
query = input()
tokenized_query = query.split(" ")
doc_scores = bm25.get_scores(tokenized_query)

# %% [markdown]
# # Getting the top 10 documents of the Query

# %%
pi = bm25.get_top_n(tokenized_query, corpus, n=10)
index = [corpus.index(i) for i in pi]

# %% [markdown]
# # The files retrived

# %%
index
# Out:
# [291, 376, 44, 1021, 559, 988, 295, 577, 165, 345]

# %% [markdown]
# # The Content of top 10 Documents

# %%
print(pi)
# Out:
# ["- widget : live score & news- watch app- dark mode- # askcricinfofollow cricket brand new espncricinfo app go easi & provid seamless experi web app . the app light , fast widest coveragediscov espncricinfo ’ content app . widest cricket coverag across world includ ipl , psl , bpl , bbl , cpl , wbbl , the ash , icc cricket world cup , t20 world cup , the hundr , counti championship , ranji trophi , sheffield shield.get : - fast live score ball ball commentary- notif updat live cricket matches- easi read latest cricket news- cricket video includ highlight , analysi , interview , press conferences- get expert opinion daniel vettori , robin uthappa , muttiah muralitharan , gautam gambhir , tom moodi , sanjay manjrekar , ajit agarkar , aakash chopra , deep dasgupta & more.visit websit http : //www.espncricinfo.com follow us @ espncricinfo twitter like us http : //www.facebook.com/cricinfo latest updates.term use - http : //disneytermsofuse.com/privaci polici - http : //www.disneyprivacycenter.comespn+ subscrib agreement - http : //es.pn/plus-termsyour california privaci right - http : //privacy.thewaltdisneycompany.com/en/current-privacy-policy/your-california-privacy-rights/do not sell my inform - http : //privacy.thewaltdisneycompany.com/en/dnsmibefor download app , pleas consid includ advertis , may target interest . you may choos control target advertis within mobil applic use mobil devic set ( exampl , re-set devic ’ advertis identifi and/or opt interest base ad ) .version 7.1.11bug fix enhancements14.5k ratingshand data provid cricinfo websit unmatch . thi applic much potenti sadli glitch let experi . sometim orient n't work properli . if zoom zoom function orient ui fix . pleas add support landscap mode especi search statsguru.at outset , i would like clarifi espncricinfo mecca thing cricket . i absolut love content ardent follow cricket match platform . thi review , howev , poor app design feel like mobil web browser age badli . the app intuit phone user . the touch target small . the page refresh smooth . there gestur incorpor . the overal user experi poor crappi . for cricket tragic like , poorli develop app barrier consum inform i need app attract new audienc game date . thi sincer plea develop decis maker cricinfo make app modern.i ’ like clarifi one thing outset , i absolut ador content cricinfo . cricinfo continu remain definit place onlin thing cricket i love decad . the poor rate app , poorli design unintuit . i guess larg espn want standard onlin properti , clearli ’ work well cricket least . sadli also true websit , terribl navig . thi real shame , i describ , best write , analysi statist sport . i wish situat address futur . the develop , espn digit media ( india ) privat limit , indic app ’ privaci practic may includ handl data describ . for inform , see develop ’ privaci polici . the follow data may use track across app websit own compani : the follow data may collect link ident : privaci practic may vari base , exampl , featur use age . learn moreenglishcricheroes-cricket score appplay-cricket livebccifancod : live cricket & scorescricket fever - live cricketparimatch : live sport bet", "welcom espn india editionwaqar youni burewala express , might actual faster gun town . you like never heard . that 's 32-year-old ihsan ullah star pakistan basebal team 's current play asian game jakarta . `` ihsan 's best pitcher pakistan . he 's play profession south korea 's probabl pitch ball 100 mile hour , '' say team coach sy babar ali sherazi.it 's 100mph wrong sport , unfortun . like rest indian sub-contin , cricket king pakistan . `` i use play district-level cricket , '' ihsan say . and might pass unrecogn play field , 's play well-known pakistani cricket . `` i 've play alongsid mohammad irfan club game tour india 2014 , '' says.h n't pakistan basebal player cricket connect . accord team offici , 70 percent team start cricket ( rest javelin thrower ) . outfield ubaid ullah anoth . `` i bowl right arm pace tandem  ...
